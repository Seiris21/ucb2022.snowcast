# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def folderinfo(path):
  
  # !date
  # !echo Contents of $path :
  # !echo
  # !echo Number of files:
  # !ls $path | wc -l
  # !echo
  # !du -h $path
  # !echo
  # !ls -clt $path | (head -n 4; echo ...; tail -n 4)

# %%
folderinfo('drive/MyDrive/snowcapstone\ team\ spring\ 2022/Sen1_Data')
# Out:
# Mon Feb 14 17:10:08 UTC 2022
# Contents of drive/MyDrive/snowcapstone team spring 2022/Sen1_Data :
#
# Number of files:
# 83001
#
# 122M	drive/MyDrive/snowcapstone team spring 2022/Sen1_Data
#
# total 124066
# -rw------- 1 root root 1234 Feb 14 05:13 ff01e8c2-19a2-4a89-af0e-608b8f40ad5f_sentinel1_VV_2019365.jpg
# -rw------- 1 root root 1244 Feb 14 05:13 fdeb8912-f9d1-445d-aadb-e943534f67fe_sentinel1_VV_2019365.jpg
# -rw------- 1 root root 1236 Feb 14 05:13 fe33672e-7ea7-4c5d-8639-96b2cc7edb0c_sentinel1_VV_2019365.jpg
# ...
# -rw------- 1 root root 1236 Feb 13 19:16 d37da01c-d9d7-4cbf-985a-af44d5a3e1e9_sentinel1_VV_2016033.jpg
# -rw------- 1 root root 1240 Feb 13 19:16 844639be-b3a6-4665-a46b-e75774f8ed50_sentinel1_VV_2016033.jpg
# -rw------- 1 root root 1233 Feb 13 19:15 6e96bf06-cbc5-45b5-a36b-e37864226099_sentinel1_VV_2016033.jpg
# -rw------- 1 root root 1248 Feb 13 19:15 4f383fb2-6cc7-48a8-9bdb-9c5d150e6eae_sentinel1_VV_2016033.jpg

# %%
folderinfo('drive/MyDrive/snowcapstone\ team\ spring\ 2022/Sen2_Data')
# Out:
# Mon Feb 14 11:41:50 UTC 2022
# Contents of drive/MyDrive/snowcapstone team spring 2022/Sen2_Data :
#
# Number of files:
# 1
#
# 15K	drive/MyDrive/snowcapstone team spring 2022/Sen2_Data
#
# total 11
# -rw------- 1 root root 10974 Feb 13 20:54 test.png
# ...

# %%
folderinfo('drive/MyDrive/snowcapstone\ team\ spring\ 2022/Copernicus_Data')
# Out:
# Mon Feb 14 11:13:13 UTC 2022
# Contents of drive/MyDrive/snowcapstone team spring 2022/Copernicus_Data :
#
# Number of files:
# 10879
#
# 2.0G	drive/MyDrive/snowcapstone team spring 2022/Copernicus_Data
#
# total 2054065
# -rw------- 1 root root     83179 Feb 13 03:00 fd0cf494-eb56-4f3f-8efb-13dd8fbf7856_copernicus90m.png
# -rw------- 1 root root    125203 Feb 13 03:00 e7f6383d-72b2-48ad-b77c-a75dd3533c9b_copernicus90m.png
# -rw------- 1 root root    129072 Feb 13 03:00 f8ac5c72-a6ef-45ec-8275-68076a3b7276_copernicus90m.png
# ...
# -rw------- 1 root root    136777 Feb 12 23:43 02c3ec4a-8de4-4284-9ec1-5a942d3d098e_copernicus90m.png
# -rw------- 1 root root    258320 Feb 12 23:42 00c4db22-a423-41a4-ada6-a8b1b04153a4_copernicus90m.png
# -rw------- 1 root root  39608824 Feb  9 05:01 copernicus_sierras2.zip
# -rw------- 1 root root 617573683 Feb  8 23:37 copernicus_sierras.zip

# %%
folderinfo('drive/MyDrive/snowcapstone\ team\ spring\ 2022/MODIS_Data')
# Out:
# Mon Feb 14 11:41:51 UTC 2022
# Contents of drive/MyDrive/snowcapstone team spring 2022/MODIS_Data :
#
# Number of files:
# 6
#
# 212M	drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MOD10A1
# 204M	drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MYD10A1
# 869M	drive/MyDrive/snowcapstone team spring 2022/MODIS_Data
#
# total 464202
# drwx------ 2 root root      4096 Feb 14 11:08 MOD10A1
# drwx------ 2 root root      4096 Feb 14 11:08 MYD10A1
# -rw------- 1 root root 203988216 Feb 13 19:03 MOD10A1_allregions1.zip
# ...

# %%
folderinfo('drive/MyDrive/snowcapstone\ team\ spring\ 2022/MODIS_Data/MOD10A1')
# Out:
# Mon Feb 14 16:25:07 UTC 2022
# Contents of drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MOD10A1 :
#
# Number of files:
# 73536
#
# 212M	drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MOD10A1
#
# total 216800
# -rw------- 1 root root 4442 Feb 14 04:52 005ad93b-c3fa-4198-a486-97c83848396a_MOD10A1_2020007.jpg
# -rw------- 1 root root 4396 Feb 14 04:52 004389c3-b0c8-47ef-9851-df1f74c5ecda_MOD10A1_2020007.jpg
# -rw------- 1 root root 4396 Feb 14 04:52 0043c28e-7f7d-49e9-8be3-139f93b281a7_MOD10A1_2020007.jpg
# ...
# -rw------- 1 root root 4059 Feb  2 21:07 01be2cc7-ef77-4e4d-80ed-c4f8139162c3_MOD10A1_2013008.jpg
# -rw------- 1 root root 4283 Feb  2 21:07 018cf1a1-f945-4097-9c47-0c4690538bb5_MOD10A1_2013008.jpg
# -rw------- 1 root root 3946 Feb  2 21:07 f6106ef5-e6fd-423b-9034-59bce18319da_MOD10A1_2013001.jpg
# -rw------- 1 root root 3456 Feb  2 21:07 df01bf44-46b8-4541-b0a4-ed1fae16ac38_MOD10A1_2013001.jpg

# %%
folderinfo('drive/MyDrive/snowcapstone\ team\ spring\ 2022/MODIS_Data/MYD10A1')
# Out:
# Mon Feb 14 16:40:59 UTC 2022
# Contents of drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MYD10A1 :
#
# Number of files:
# 73523
#
# 204M	drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MYD10A1
#
# total 207946
# -rw------- 1 root root 2916 Feb 13 07:40 fe33672e-7ea7-4c5d-8639-96b2cc7edb0c_MYD10A1_2019365.jpg
# -rw------- 1 root root 1379 Feb 13 07:40 ff01e8c2-19a2-4a89-af0e-608b8f40ad5f_MYD10A1_2019365.jpg
# -rw------- 1 root root 4342 Feb 13 07:40 fde3221a-9ce3-45a9-857f-bd196b07aa05_MYD10A1_2019365.jpg
# ...
# -rw------- 1 root root 4263 Feb  3 09:19 147d5eb4-e574-47e4-994a-8a2908c06050_MYD10A1_2013001.jpg
# -rw------- 1 root root 3527 Feb  3 09:19 2700b724-e8c8-4715-acef-f448b252e07c_MYD10A1_2013001.jpg
# -rw------- 1 root root 4127 Feb  3 09:19 01be2cc7-ef77-4e4d-80ed-c4f8139162c3_MYD10A1_2013001.jpg
# -rw------- 1 root root 4322 Feb  3 09:19 018cf1a1-f945-4097-9c47-0c4690538bb5_MYD10A1_2013001.jpg

# %%
# !du -h drive/MyDrive/snowcapstone\ team\ spring\ 2022/Copernicus_Data
# Out:
# 2.0G	drive/MyDrive/snowcapstone team spring 2022/Copernicus_Data

# %%
# !du -h --exclude='*.zip' drive/MyDrive/snowcapstone\ team\ spring\ 2022/Copernicus_Data
# Out:
# 1.4G	drive/MyDrive/snowcapstone team spring 2022/Copernicus_Data

# %%
# !date
# !du -h drive/MyDrive/snowcapstone\ team\ spring\ 2022/MODIS_Data
# Out:
# Mon Feb 14 10:58:42 UTC 2022
# du: cannot read directory 'drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MOD10A1': Input/output error
# 4.0K	drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MOD10A1
# du: cannot read directory 'drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MYD10A1': Input/output error
# 4.0K	drive/MyDrive/snowcapstone team spring 2022/MODIS_Data/MYD10A1
# 454M	drive/MyDrive/snowcapstone team spring 2022/MODIS_Data

# %%
# %%time
# !diff --report-identical-files drive/MyDrive/snowcapstone\ team\ spring\ 2022/Sen1_Data/f8f9bacd-982a-4187-891c-e4c453f0a49b_sentinel1_VV_2019085\ \(1\).jpg drive/MyDrive/snowcapstone\ team\ spring\ 2022/Sen1_Data/f8f9bacd-982a-4187-891c-e4c453f0a49b_sentinel1_VV_2019085.jpg
# Out:
# Files drive/MyDrive/snowcapstone team spring 2022/Sen1_Data/f8f9bacd-982a-4187-891c-e4c453f0a49b_sentinel1_VV_2019085 (1).jpg and drive/MyDrive/snowcapstone team spring 2022/Sen1_Data/f8f9bacd-982a-4187-891c-e4c453f0a49b_sentinel1_VV_2019085.jpg are identical
# CPU times: user 11.9 ms, sys: 7.37 ms, total: 19.3 ms
# Wall time: 818 ms
