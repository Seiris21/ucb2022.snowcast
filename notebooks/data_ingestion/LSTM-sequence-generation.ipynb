# %%
import torch

# %%
import pandas as pd
import datetime
import numpy as np

# %%
data = pd.read_csv('/home/ubuntu/SnowData/Final_CNN_Dataframe.csv')

weather = pd.read_csv('/home/ubuntu/SnowData/GRIDMET_Weather_Data.csv')

# %%
columns = list(data.columns)
columns
# Out:
# ['cell_id',
#  'date',
#  'SWE',
#  'mean_inversed_swe',
#  'mean_local_swe',
#  'median_local_swe',
#  'max_local_swe',
#  'min_local_swe',
#  'mean_local_elevation',
#  'median_local_elevation',
#  'max_local_elevation',
#  'min_local_elevation',
#  'MOD10A1_SnowCover',
#  'MOD10A1_Albedo',
#  'MOD10A1_NDSI',
#  'MYD10A1_SnowCover',
#  'MYD10A1_Albedo',
#  'MYD10A1_NDSI',
#  'copernicus_filelocations',
#  'sentinel1_filelocation',
#  'sentinel2a_filelocation',
#  'sentinel2b_filelocation']

# %%
features = ['date', 'SWE', 'mean_inversed_swe', 'mean_local_swe',
       'median_local_swe', 'max_local_swe', 'min_local_swe',
       'mean_local_elevation', 'median_local_elevation', 'max_local_elevation',
       'min_local_elevation', 'copernicus_filelocations', 'MOD10A1_SnowCover',
       'MOD10A1_Albedo', 'MOD10A1_NDSI', 'MYD10A1_SnowCover', 'MYD10A1_Albedo',
       'MYD10A1_NDSI']

# %%
weather_features =  ['precip_daily','wind_dir_avg','temp_min','temp_max','wind_vel']

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
weather['date'] = pd.to_datetime(weather['date'])

# %%
#Get years in dataset
years = []
for i in data['date']:
    if i.year not in years:
        years.append(i.year)

# %%
years
# Out:
# [2017, 2019, 2016, 2018]

# %%
#If we want to drop columns from sequence
drop_columns = []
drop_indexes = []
for i in columns:
    if i in drop_columns:
        drop_indexes.append(columns.index(i))

# %%
data.head()
# Out:
#                  cell_id       date        SWE  mean_inversed_swe  \
# 0   ASO_50M_SWE_USCARC_8 2017-07-17  48.561301           4.697841
# 1   ASO_50M_SWE_USCARC_9 2017-07-17  33.924218           4.736198
# 2  ASO_50M_SWE_USCARC_26 2017-07-17  31.831418           5.221427
# 3  ASO_50M_SWE_USCARC_27 2017-07-17  41.723133           5.322858
# 4  ASO_50M_SWE_USCARC_28 2017-07-17  42.693821           5.377803
#
#    mean_local_swe  median_local_swe  max_local_swe  min_local_swe  \
# 0        4.685963          1.381988      18.482857       0.573913
# 1        4.685963          1.381988      18.482857       0.573913
# 2        4.685963          1.381988      18.482857       0.573913
# 3        4.685963          1.381988      18.482857       0.573913
# 4        4.685963          1.381988      18.482857       0.573913
#
#    mean_local_elevation  median_local_elevation  ...  MOD10A1_SnowCover  \
# 0               2834.64                 2880.36  ...           0.761684
# 1               2834.64                 2880.36  ...           0.666698
# 2               2834.64                 2880.36  ...           0.717794
# 3               2834.64                 2880.36  ...           0.758141
# 4               2834.64                 2880.36  ...           0.732553
#
#    MOD10A1_Albedo  MOD10A1_NDSI  MYD10A1_SnowCover  MYD10A1_Albedo  \
# 0        0.367174      0.766883           0.814966        0.345533
# 1        0.326389      0.669003           0.790095        0.339398
# 2        0.387605      0.721743           0.660893        0.377931
# 3        0.388365      0.761231           0.754647        0.370129
# 4        0.393211      0.737283           0.753537        0.346098
#
#    MYD10A1_NDSI                           copernicus_filelocations  \
# 0      0.818492  /home/ubuntu/SnowData/CopernicusData/ASO_50M_S...
# 1      0.792235  /home/ubuntu/SnowData/CopernicusData/ASO_50M_S...
# 2      0.665706  /home/ubuntu/SnowData/CopernicusData/ASO_50M_S...
# 3      0.758559  /home/ubuntu/SnowData/CopernicusData/ASO_50M_S...
# 4      0.757798  /home/ubuntu/SnowData/CopernicusData/ASO_50M_S...
#
#                               sentinel1_filelocation  \
# 0  /home/ubuntu/SnowData/Sen1_Data_poly/ASO_50M_S...
# 1  /home/ubuntu/SnowData/Sen1_Data_poly/ASO_50M_S...
# 2  /home/ubuntu/SnowData/Sen1_Data_poly/ASO_50M_S...
# 3  /home/ubuntu/SnowData/Sen1_Data_poly/ASO_50M_S...
# 4  /home/ubuntu/SnowData/Sen1_Data_poly/ASO_50M_S...
#
#                              sentinel2a_filelocation  \
# 0  /home/ubuntu/SnowData/Sen2_DataA_poly/ASO_50M_...
# 1  /home/ubuntu/SnowData/Sen2_DataA_poly/ASO_50M_...
# 2  /home/ubuntu/SnowData/Sen2_DataA_poly/ASO_50M_...
# 3  /home/ubuntu/SnowData/Sen2_DataA_poly/ASO_50M_...
# 4  /home/ubuntu/SnowData/Sen2_DataA_poly/ASO_50M_...
#
#                              sentinel2b_filelocation
# 0  /home/ubuntu/SnowData/Sen2_DataB_poly/ASO_50M_...
# 1  /home/ubuntu/SnowData/Sen2_DataB_poly/ASO_50M_...
# 2  /home/ubuntu/SnowData/Sen2_DataB_poly/ASO_50M_...
# 3  /home/ubuntu/SnowData/Sen2_DataB_poly/ASO_50M_...
# 4  /home/ubuntu/SnowData/Sen2_DataB_poly/ASO_50M_...
#
# [5 rows x 22 columns]

# %%
weather.head()
# Out:
#                    cell_id                                           geometry  \
# 0  ASO_50M_SWE_USCAJW_3012  POLYGON ((-119.3966606691139 37.58805474778629...
# 1  ASO_50M_SWE_USCAJW_3012  POLYGON ((-119.3966606691139 37.58805474778629...
# 2  ASO_50M_SWE_USCAJW_3012  POLYGON ((-119.3966606691139 37.58805474778629...
# 3  ASO_50M_SWE_USCAJW_3012  POLYGON ((-119.3966606691139 37.58805474778629...
# 4  ASO_50M_SWE_USCAJW_3012  POLYGON ((-119.3966606691139 37.58805474778629...
#
#         date  precip_daily  wind_dir_avg  temp_min  temp_max  wind_vel
# 0 2019-03-12           0.0        114.00    262.80    275.20       5.0
# 1 2019-04-18           0.0        146.00    268.90    286.20       3.8
# 2 2019-04-14           0.0        248.00    268.90    285.50       3.7
# 3 2016-07-05           0.0        215.42    279.89    294.03       4.0
# 4 2017-01-25           0.0        196.00    255.50    267.50       3.5

# %%
subset = data[data['cell_id']=='ASO_50M_SWE_USCAJW_3012']
subset.head()
# Out:
#                        cell_id       date  SWE  mean_inversed_swe  \
# 77179  ASO_50M_SWE_USCAJW_3012 2019-03-15  0.0          43.919107
#
#        mean_local_swe  median_local_swe  max_local_swe  min_local_swe  \
# 77179       44.017429         46.028571      54.891429      32.964286
#
#        mean_local_elevation  median_local_elevation  ...  MOD10A1_SnowCover  \
# 77179              2359.152                 2407.92  ...           0.787285
#
#        MOD10A1_Albedo  MOD10A1_NDSI  MYD10A1_SnowCover  MYD10A1_Albedo  \
# 77179        0.495962        0.7901           0.784442        0.495653
#
#        MYD10A1_NDSI                           copernicus_filelocations  \
# 77179      0.788866  /home/ubuntu/SnowData/CopernicusData/ASO_50M_S...
#
#                                   sentinel1_filelocation  \
# 77179  /home/ubuntu/SnowData/Sen1_Data_poly/ASO_50M_S...
#
#                                  sentinel2a_filelocation  \
# 77179  /home/ubuntu/SnowData/Sen2_DataA_poly/ASO_50M_...
#
#                                  sentinel2b_filelocation
# 77179  /home/ubuntu/SnowData/Sen2_DataB_poly/ASO_50M_...
#
# [1 rows x 22 columns]

# %%
subset.date.values[0]
# Out:
# numpy.datetime64('2019-03-15T00:00:00.000000000')

# %%
d = pd.date_range(end='2019-07-05', periods=10)
d
# Out:
# DatetimeIndex(['2019-06-26', '2019-06-27', '2019-06-28', '2019-06-29',
#                '2019-06-30', '2019-07-01', '2019-07-02', '2019-07-03',
#                '2019-07-04', '2019-07-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
#%%time
#for date in d:
#    query = weather.loc[(weather['cell_id']=='ASO_50M_SWE_USCAKC_1754') & (weather['date']==date)]

# %%
# %%time
#Drop duplicate rows
weather = weather.drop_duplicates(subset=['cell_id', 'date'], keep='first')
weather.loc[(weather.cell_id == 'ASO_50M_SWE_USCATE_1893') & (weather.date.isin(d))].sort_values('date')
# Out:
# CPU times: user 967 ms, sys: 312 ms, total: 1.28 s
# Wall time: 1.28 s
#                          cell_id  \
# 2623749  ASO_50M_SWE_USCATE_1893
# 2623725  ASO_50M_SWE_USCATE_1893
# 2623699  ASO_50M_SWE_USCATE_1893
# 2623671  ASO_50M_SWE_USCATE_1893
# 2623640  ASO_50M_SWE_USCATE_1893
# 2623606  ASO_50M_SWE_USCATE_1893
# 2623560  ASO_50M_SWE_USCATE_1893
# 2623547  ASO_50M_SWE_USCATE_1893
# 2623539  ASO_50M_SWE_USCATE_1893
# 2623774  ASO_50M_SWE_USCATE_1893
#
#                                                   geometry       date  \
# 2623749  POLYGON ((-119.59637727916386 37.8995447364871... 2019-06-26
# 2623725  POLYGON ((-119.59637727916386 37.8995447364871... 2019-06-27
# 2623699  POLYGON ((-119.59637727916386 37.8995447364871... 2019-06-28
# 2623671  POLYGON ((-119.59637727916386 37.8995447364871... 2019-06-29
# 2623640  POLYGON ((-119.59637727916386 37.8995447364871... 2019-06-30
# 2623606  POLYGON ((-119.59637727916386 37.8995447364871... 2019-07-01
# 2623560  POLYGON ((-119.59637727916386 37.8995447364871... 2019-07-02
# 2623547  POLYGON ((-119.59637727916386 37.8995447364871... 2019-07-03
# 2623539  POLYGON ((-119.59637727916386 37.8995447364871... 2019-07-04
# 2623774  POLYGON ((-119.59637727916386 37.8995447364871... 2019-07-05
#
#          precip_daily  wind_dir_avg  temp_min  temp_max  wind_vel
# 2623749           0.0         172.0     277.3     292.0       2.3
# 2623725           0.0         209.0     275.6     288.7       2.4
# 2623699           0.0         241.0     274.5     288.2       1.9
# 2623671           0.0         127.0     274.8     286.8       1.4
# 2623640           0.0         168.0     274.7     291.3       2.0
# 2623606           0.0         179.0     276.9     291.6       1.9
# 2623560           0.0         194.0     276.7     292.2       1.8
# 2623547           0.0         195.0     276.5     291.9       2.2
# 2623539           0.0         228.0     275.9     290.7       2.0
# 2623774           0.0         235.0     275.6     292.3       2.3

# %%
data = data[['cell_id','date']]

# %%
data.head()
# Out:
#                  cell_id       date
# 0   ASO_50M_SWE_USCARC_8 2017-07-17
# 1   ASO_50M_SWE_USCARC_9 2017-07-17
# 2  ASO_50M_SWE_USCARC_26 2017-07-17
# 3  ASO_50M_SWE_USCARC_27 2017-07-17
# 4  ASO_50M_SWE_USCARC_28 2017-07-17

# %%
# %%time
problems = pd.DataFrame(columns=['cell_id','date','ten'])
lstm_length=10
for (_, data_id, data_date) in data.itertuples():
    date_range = pd.date_range(end=data_date, periods=lstm_length)
        
    sequence = weather.loc[(weather['cell_id'] == data_id) 
                                       & (weather.date.isin(date_range))].sort_values('date')
    if list(sequence.shape) != [10,8]:
        print(sequence.shape,data_id,data_date)
        row = pd.DataFrame(data = [[data_id,data_date,list(sequence.shape)]],columns=['cell_id','date','ten'])
        problems = pd.concat([problems,row],axis=0,ignore_index=True)
# Out:
# (1, 8) ASO_50M_SWE_USCAKC_1753 2019-04-28 00:00:00
# (0, 8) ASO_50M_SWE_USCAKC_1754 2019-04-28 00:00:00
# (2, 8) ASO_50M_SWE_USCAKC_1755 2019-04-28 00:00:00
# (8, 8) ASO_50M_SWE_USCAKC_2222 2019-04-28 00:00:00
# (0, 8) ASO_50M_SWE_USCAKC
2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3237 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3238 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3239 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3240 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3241 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3242 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3243 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3244 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3245 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3246 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3247 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3248 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3280 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3281 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3282 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3283 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3284 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3285 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3286 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3287 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3288 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3289 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3290 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3291 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3292 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3293 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3294 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3295 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3296 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3297 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3298 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3299 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3300 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3301 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3302 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3303 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3304 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3305 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3306 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3307 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3308 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3309 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3310 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3311 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3312 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3346 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3347 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3348 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3349 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3350 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3351 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3352 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3353 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3354 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3355 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3356 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3357 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3358 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3359 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3360 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3361 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3362 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3363 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3364 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3365 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3366 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3367 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3368 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3369 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3370 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3371 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3372 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3373 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3374 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3375 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3376 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3377 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3411 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3412 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3413 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3414 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3415 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3416 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3417 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3418 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3419 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3420 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3421 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3422 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3423 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3424 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3425 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3426 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3427 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3428 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3429 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3430 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3431 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3432 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3433 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3434 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3435 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3436 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3437 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3438 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3439 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3440 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3441 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3442 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3443 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3477 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3478 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3479 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3480 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3481 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3482 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3483 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3486 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3487 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3488 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3489 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3490 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3491 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3492 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3493 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3494 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3495 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3496 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3497 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3498 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3499 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3500 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3501 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3502 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3503 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3504 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3505 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3506 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3507 2017-08-16 00:00:00
# (9, 8) ASO_50M_SWE_USCATB_3508 2017-08-16 00:00:00
# (3, 8) ASO_50M_SWE_USCAKC_1753 2019-03-16 00:00:00
# (0, 8) ASO_50M_SWE_USCAKC_1754 2019-03-16 00:00:00
# (2, 8) ASO_50M_SWE_USCAKC_1755 2019-03-16 00:00:00
# (8, 8) ASO_50M_SWE_USCAKC_2222 2019-03-16 00:00:00
# (0, 8) ASO_50M_SWE_USCAKC_2223 2019-03-16 00:00:00
# (1, 8) ASO_50M_SWE_USCAKC_2224 2019-03-16 00:00:00

# %%
#pre-generate everything
weather_ts = pd.DataFrame(columns=['cell_id','date','sequence'])
weather_f = ['precip_daily','wind_dir_avg','temp_min','temp_max','wind_vel']
seq_length = 10
for index, row in data.iterrows():
    date_range = pd.date_range(end=row.date, periods=lstm_length)
    ts=[]
    for date in date_range:
        query = weather.loc[(weather['cell_id']==row.cell_id) & (weather['date']==date)]
        if not query.empty:
            single=[]
            for feature in weather_f:
                value = query[feature]
                if np.isnan(value):
                    value=-1
                single.append(value)
            ts.append(single)
        else:
            #-1 for missing values as Nan was causing issues, and 0 is a valid value
            ts.append([-1,-1,-1,-1,-1])
    
    row = pd.DataFrame(data = [[row.cell_id,row.date,ts]],columns=['cell_id','date','sequence'])

    weather_ts.concat([weather_ts,row],axis=0,ignore_index=True)
            
weather_ts = sequences.reset_index(drop=True)

# %%
weather_ts.sequence.values[0]
# Out:
# [[28.8, 213.0, 270.2, 276.1, 8.9],
#  [48.7, 215.0, 267.4, 274.8, 12.4],
#  [12.8, 213.0, 265.5, 275.4, 6.0],
#  [1.7, 248.0, 261.3, 271.0, 5.9],
#  [2.0, 224.0, 262.0, 273.0, 5.2],
#  [3.8, 121.0, 259.7, 272.2, 2.8],
#  [0.0, 114.0, 262.8, 275.2, 5.0],
#  [2.0, 226.0, 262.3, 278.6, 5.8],
#  [0.0, 194.0, 260.3, 273.3, 4.8],
#  [0.0, 117.0, 261.1, 277.5, 4.0]]

# %%
a
# Out:
#                          cell_id  \
# 5323119  ASO_50M_SWE_USCAJW_3012
# 5323085  ASO_50M_SWE_USCAJW_3012
# 5323039  ASO_50M_SWE_USCAJW_3012
# 82       ASO_50M_SWE_USCAJW_3012
# 56       ASO_50M_SWE_USCAJW_3012
# 29       ASO_50M_SWE_USCAJW_3012
# 0        ASO_50M_SWE_USCAJW_3012
# 5323103  ASO_50M_SWE_USCAJW_3012
# 5323065  ASO_50M_SWE_USCAJW_3012
# 5323021  ASO_50M_SWE_USCAJW_3012
#
#                                                   geometry       date  \
# 5323119  POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-06
# 5323085  POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-07
# 5323039  POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-08
# 82       POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-09
# 56       POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-10
# 29       POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-11
# 0        POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-12
# 5323103  POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-13
# 5323065  POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-14
# 5323021  POLYGON ((-119.3966606691139 37.58805474778629... 2019-03-15
#
#          precip_daily  wind_dir_avg  temp_min  temp_max  wind_vel
# 5323119          28.8         213.0     270.2     276.1       8.9
# 5323085          48.7         215.0     267.4     274.8      12.4
# 5323039          12.8         213.0     265.5     275.4       6.0
# 82                1.7         248.0     261.3     271.0       5.9
# 56                2.0         224.0     262.0     273.0       5.2
# 29                3.8         121.0     259.7     272.2       2.8
# 0                 0.0         114.0     262.8     275.2       5.0
# 5323103           2.0         226.0     262.3     278.6       5.8
# 5323065           0.0         194.0     260.3     273.3       4.8
# 5323021           0.0         117.0     261.1     277.5       4.0

# %%
a.drop(['cell_id','geometry','date'],axis=1,inplace=True)
a
# Out:
#          precip_daily  wind_dir_avg  temp_min  temp_max  wind_vel
# 5323119          28.8         213.0     270.2     276.1       8.9
# 5323085          48.7         215.0     267.4     274.8      12.4
# 5323039          12.8         213.0     265.5     275.4       6.0
# 82                1.7         248.0     261.3     271.0       5.9
# 56                2.0         224.0     262.0     273.0       5.2
# 29                3.8         121.0     259.7     272.2       2.8
# 0                 0.0         114.0     262.8     275.2       5.0
# 5323103           2.0         226.0     262.3     278.6       5.8
# 5323065           0.0         194.0     260.3     273.3       4.8
# 5323021           0.0         117.0     261.1     277.5       4.0

# %%
a = a.replace(0,np.NaN)
a = a.fillna(-1)

# %%
a.values.tolist()
# Out:
# [[28.8, 213.0, 270.2, 276.1, 8.9],
#  [48.7, 215.0, 267.4, 274.8, 12.4],
#  [12.8, 213.0, 265.5, 275.4, 6.0],
#  [1.7, 248.0, 261.3, 271.0, 5.9],
#  [2.0, 224.0, 262.0, 273.0, 5.2],
#  [3.8, 121.0, 259.7, 272.2, 2.8],
#  [-1.0, 114.0, 262.8, 275.2, 5.0],
#  [2.0, 226.0, 262.3, 278.6, 5.8],
#  [-1.0, 194.0, 260.3, 273.3, 4.8],
#  [-1.0, 117.0, 261.1, 277.5, 4.0]]

# %%
# %%time
torch.tensor(a.values.tolist(),dtype=torch.float32).size()
# Out:
# CPU times: user 121 µs, sys: 0 ns, total: 121 µs
# Wall time: 113 µs
# torch.Size([10, 5])

# %%
for i in range(0,len(sequences.iloc[99].sequence)):
    if i != seq_length:
        print(f"Sequence Position: {i}")
    else:
        print("Goal")
    print(sequences.iloc[99].sequence[i][1],sequences.iloc[99].sequence[i][12])
    print('________________________________')
# Out:
# Sequence Position: 0
# 2019-06-25 00:00:00 /home/ubuntu/SnowData/CopernicusData/018cf1a1-f945-4097-9c47-0c4690538bb5_copernicus.png
# ________________________________
# Sequence Position: 1
# 2019-12-03 00:00:00 /home/ubuntu/SnowData/CopernicusData/018cf1a1-f945-4097-9c47-0c4690538bb5_copernicus.png
# ________________________________
# Sequence Position: 2
# 2019-12-10 00:00:00 /home/ubuntu/SnowData/CopernicusData/018cf1a1-f945-4097-9c47-0c4690538bb5_copernicus.png
# ________________________________
# Sequence Position: 3
# 2019-12-17 00:00:00 /home/ubuntu/SnowData/CopernicusData/018cf1a1-f945-4097-9c47-0c4690538bb5_copernicus.png
# ________________________________
# Sequence Position: 4
# 2019-12-24 00:00:00 /home/ubuntu/SnowData/CopernicusData/018cf1a1-f945-4097-9c47-0c4690538bb5_copernicus.png
# ________________________________
# Goal
# 2019-12-31 00:00:00 /home/ubuntu/SnowData/CopernicusData/018cf1a1-f945-4097-9c47-0c4690538bb5_copernicus.png
# ________________________________

# %%
#Option 2,  Just change the dataloader

#Datasets are how pytorch knows how to read in the data
class SWEDataset(torch.utils.data.Dataset):
    def __init__(self, df, meta_df, test = False):
        self.df = df
        self.tabular = meta_df
        
        #First we must specify the path to the images
        self.copernicus_file_names = df['copernicus_filelocations'].values
        self.sentinel1_file_names = df['sentinel1_filelocation'].values
        self.sentinel2a_file_names = df['sentinel2a_filelocation'].values
        self.sentinel2b_file_names = df['sentinel2b_filelocation'].values
        #The only transform we want to do right now is the resizing
        self._transform = T.Resize(size= (args.imagesize, args.imagesize))
        
        #We specify the tabular feature columns
        self.meta = df[feature_cols].values
        #Now we specify the targets
        self.targets = df['SWE_Scaled'].values
        #Finally we specify if this is training or test
        self.test = test
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        #Get the image, scale it to between 0-1 and resize it
        copernicus_img_path = self.copernicus_file_names[index]
        copernicus_img = read_image(copernicus_img_path,mode = torchvision.io.image.ImageReadMode.RGB) / 255
        copernicus_img = self._transform(copernicus_img)
        
        sentinel1_img_path = self.sentinel1_file_names[index]
        sentinel1_img = read_image(sentinel1_img_path, mode = torchvision.io.image.ImageReadMode.RGB) / 255
        sentinel1_img = self._transform(sentinel1_img)
        
        sentinel2a_img_path = self.sentinel2a_file_names[index]
        sentinel2a_img = read_image(sentinel2a_img_path, mode = torchvision.io.image.ImageReadMode.RGB) / 255
        sentinel2a_img = self._transform(sentinel2a_img)
        
        sentinel2b_img_path = self.sentinel2b_file_names[index]
        sentinel2b_img = read_image(sentinel2b_img_path, mode = torchvision.io.image.ImageReadMode.RGB) / 255
        sentinel2b_img = self._transform(sentinel2b_img)

        #Pull from weather data and generate time-series
        #Variables = precip_daily|wind_dir_avg|temp_min|temp_max|wind_vel
        date_range = pd.date_range(end=self.date[index], periods=self.seq_len)
        ts = []
        for date in date_range:
            query = self.timeseries.loc[(self.timeseries['cell_id']==self.cell_id[index]) & (self.timeseries['date']==date)]
            if not query.empty:
                single_point=[]
                for feature in args.lstm_features:
                    value = list(query[feature])[0]
                    if np.isnan(value):
                        value=-1
                    single_point.append(value)
                
                ts.append(single)
            else:
                #-1 for missing values as Nan was causing issues, and 0 is a valid value
                ts.append([-1,-1,-1,-1,-1])
        ts = torch.tensor(ts,dtype=torch.float32)
        
        
        #Pull in the features for our batch
        meta = self.meta[index, :]
        
        #Specify the target based on whether this is training or test
        if self.test:
          target = 0
        else:
          target = self.targets[index]
            
        return copernicus_img, sentinel1_img, sentinel2a_img, sentinel2b_img, target, meta , ts
